# %%
LAST_NAME = "Acapulco"
STUDENT_ID = "TUPM-26-1874"
SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(digit) for digit in STUDENT_ID if digit.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student:", LAST_NAME)
print("Seed Digit:", SEED_DIGIT)
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student: Acapulco
# Seed Digit: 4
# Digit Sum: 28
# Surname Length: 8

# %%
def greet():
    print("=" * 40)
    print(f"System Initialized for: {LAST_NAME}")
    print("=" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code
greet()
print("Identity Code:", identity_code())
# Out:
# ========================================
# System Initialized for: Acapulco
# ========================================
# Identity Code: 32

# %%
global_value = ID_SUM

def scope_test():
    global_value = SEED_DIGIT
    print("Inside function", global_value)

scope_test()
print("Outside function", global_value)
# Out:
# Inside function 4
# Outside function 28

# %%
def user_summary(title, *scores, **info):
    print(f"=== {title} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average:", round(average, 2))

    for k,v in info.items():
        print(f"{k}: {v}")

    return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id=STUDENT_ID,
    surname=LAST_NAME,
)
# Out:
# === Acapulco Academic Report ===
# Scores: (40, 28, 40)
# Total: 108
# Average: 36.0
# id: TUPM-26-1874
# surname: Acapulco

# %%
def compute_area(radius):
    return 3.1416 * radius**2

area = compute_area(SEED_DIGIT + 2)
print("Computed Area:", round(area, 2))
# Out:
# Computed Area: 113.1

# %%
def safe_calculator(x,y):
    try:
        result = x / y
    except ZeroDivisionError:
        result = "UNDEFINED"
    return result

print("Calculation Result:", safe_calculator(ID_SUM, SEED_DIGIT))
# Out:
# Calculation Result: 7.0

# %%
def factorial(n):
    if n <= 1:
        return 1
    return n * factorial(n - 1)

print("Factorial Result:", factorial(SEED_DIGIT))
# Out:
# Factorial Result: 24

# %%
def reverse(text):
    if len(text) <= 1:
        return text
    return text[-1] + reverse(text[:-1])

print("Reversed Name:", reverse(LAST_NAME.upper()))
# Out:
# Reversed Name: OCLUPACA

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print(f"Executing:", func.__name__)
        return func(*args, **kwargs)
    return wrapper

@logger
def multiply(x, y):
    return x * y

print("Multiplication:", multiply(SEED_DIGIT, NAME_LENGTH))
# Out:
# Executing: multiply
# Multiplication: 32

# %%
data = list(range(1, SEED_DIGIT + 10))
squared = list(map(lambda x: x**2, data))

print("Squared Values:", squared)
# Out:
# Squared Values: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169]

# %%
def even_square(limit):
    for i in range(limit):
        if i % 2 == 0:
            yield i**2

for value in even_square(NAME_LENGTH + SEED_DIGIT):
    print(value)
# Out:
# 0
# 4
# 16
# 36
# 64
# 100
